# %%
import sp_library as sp

# %%
start_time = '2017-08-20T01:01:01.000Z'
end_time = '2017-08-23T01:01:01.000Z'

# %%
data = sp.send_data_requests(start_time, end_time)

# %%
data
# Out:
#                              refdes    method               stream  \
# 0       CE04OSPS-PC01B-4A-CTDPFA109  streamed  ctdpf_optode_sample
# 1       CE04OSPS-PC01B-4A-CTDPFA109  streamed  ctdpf_optode_sample
# 2       CE04OSPS-PC01B-4A-CTDPFA109  streamed  ctdpf_optode_sample
# 3       CE04OSPS-PC01B-4A-CTDPFA109  streamed  ctdpf_optode_sample
# 4       CE04OSPS-PC01B-4A-CTDPFA109  streamed  ctdpf_optode_sample
# 5       CE04OSPS-PC01B-4A-CTDPFA109  streamed  ctdpf_optode_sample
# 6       CE04OSPS-PC01B-4A-CTDPFA109  streamed  ctdpf_optode_sample
# 7       CE04OSPS-PC01B-4A-CTDPFA109  streamed  ctdpf_optode_sample
# 8       CE04OSPS-PC01B-4A-CTDPFA109  streamed  ctdpf_optode_sample
# 9       CE04OSPS-PC01B-4A-CTDPFA109  streamed  ctdpf_optode_sample
# 10      CE04OSPS-PC01B-4A-CTDPFA109  streamed  ctdpf_optode_sample
# 11      CE04OSPS-PC01B-4A-CTDPFA109  streamed  ctdpf_optode_sample
# 12      CE04OSPS-PC01B-4A-CTDPFA109  streamed  ctdpf_optode_sample
# ...
